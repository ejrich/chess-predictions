# %% [markdown]
# ## Deep Learning Move Convolutional Engine
#
# By Evan Richardson
#
# This notebook is dedicated to producing the move-selecting engine for the move prediction engine.  These models are used to select the location to move to, with each model corresponding to a particular piece.

# %%
import tensorflow
print(tensorflow.__version__)

import numpy as np
import pandas as pd
# from google.colab import drive
from sklearn.model_selection import train_test_split
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten
# Out:
# 1.13.0-rc1

# %%
# drive.mount('/content/gdrive')
df = pd.read_csv("../data/2018_games_dl_pred.csv")

# %%
df.head()
# Out:
#    Result  Move  Color  Piece  CurrentFile  CurrentRank  NewFile  NewRank  \
# 0       1     1      1      1            4            1        4        3
# 1       1     2      1      1            5            1        5        3
# 2       1     3      1      3            6            0        5        2
# 3       1     4      1      1            3            1        3        2
# 4       1     5      1      1            4            3        4        4
#
#     a1   b1 ...    g7   h7   a8   b8    c8    d8    e8    f8   g8   h8
# 0  2.0  3.0 ...   7.0  7.0  8.0  9.0  10.0  11.0  12.0  10.0  9.0  8.0
# 1  2.0  3.0 ...   7.0  7.0  8.0  9.0  10.0  11.0  12.0  10.0  9.0  8.0
# 2  2.0  3.0 ...   7.0  7.0  8.0  9.0  10.0  11.0  12.0  10.0  9.0  8.0
# 3  2.0  3.0 ...   7.0  7.0  8.0  NaN  10.0  11.0  12.0  10.0  9.0  8.0
# 4  2.0  3.0 ...   7.0  7.0  8.0  NaN  10.0  11.0  12.0  10.0  9.0  8.0
#
# [5 rows x 72 columns]

# %%
df.shape
# Out:
# (2863632, 72)

# %%
pawn_moves = df.loc[df['Piece'] == 1]
rook_moves = df.loc[df['Piece'] == 2]
knight_moves = df.loc[df['Piece'] == 3]
bishop_moves = df.loc[df['Piece'] == 4]
queen_moves = df.loc[df['Piece'] == 5]
king_moves = df.loc[df['Piece'] == 6]

print(pawn_moves.shape, rook_moves.shape, knight_moves.shape, bishop_moves.shape, queen_moves.shape, king_moves.shape)
# Out:
# (774689, 72) (468141, 72) (504619, 72) (466076, 72) (349035, 72) (301072, 72)

# %%
def translateGameStates(df):
  states = []

  for position in df.values:
    gameState = np.zeros((8, 8, 6))
    squares = position[-64:]

    for rank in range(8):
      for file in range(8):
        index = rank * 8 + file
        piece = squares[index]

        if piece > 6:
          gameState[rank][file][int(piece) - 7] = -1
        elif piece > 0:
          gameState[rank][file][int(piece) - 1] = 1

    states.append(gameState)

  return np.array(states)

# %% [markdown]
# The input "image" that is created to be consumed by the network is an 8x8 representation of the board with 6 output channels, with a 1 representing a friendly piece (in this model's case only white), and a -1 representing an enemy piece (black).  The 6 channels also correspond to a particular piece.

# %%
def translateOutputSet(df, file_col, rank_col):
  states = []

  for position in df.values:
    state = np.zeros(64)

    file = position[file_col]
    rank = position[rank_col]

    state[int(rank) * 8 + int(file)] = 1
    states.append(state)

  return np.array(states)

# %% [markdown]
# The output shape represents an 8x8 board, with a 1 representing the selected move.  For use with a dense layer, the board is flattened to a 64 length array.

# %%
def createTrainAndTestSets(df):
  train, test = train_test_split(df)
  print(df.shape, train.shape, test.shape)
  
  x_train = translateGameStates(train)
  x_test = translateGameStates(test)

  y_train = translateOutputSet(train, 6, 7)
  y_test = translateOutputSet(test, 6, 7)
  
  return (x_train, x_test, y_train, y_test)

# %%
pawn_x_train, pawn_x_test, pawn_y_train, pawn_y_test = createTrainAndTestSets(pawn_moves)
rook_x_train, rook_x_test, rook_y_train, rook_y_test = createTrainAndTestSets(rook_moves)
knight_x_train, knight_x_test, knight_y_train, knight_y_test = createTrainAndTestSets(knight_moves)
bishop_x_train, bishop_x_test, bishop_y_train, bishop_y_test = createTrainAndTestSets(bishop_moves)
queen_x_train, queen_x_test, queen_y_train, queen_y_test = createTrainAndTestSets(queen_moves)
king_x_train, king_x_test, king_y_train, king_y_test = createTrainAndTestSets(king_moves)
# Out:
# (774689, 72) (581016, 72) (193673, 72)
# (468141, 72) (351105, 72) (117036, 72)
# (504619, 72) (378464, 72) (126155, 72)
# (466076, 72) (349557, 72) (116519, 72)
# (349035, 72) (261776, 72) (87259, 72)
# (301072, 72) (225804, 72) (75268, 72)

# %%
input_shape = (8, 8, 6)
print(input_shape)
# Out:
# (8, 8, 6)

# %%
def train_model(x_train, x_test, y_train, y_test):
  batch_size = 250
  num_classes = 64
  epochs = 15

  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
  model.add(Conv2D(128, (3, 3), activation='relu'))
  model.add(Flatten())
  model.add(Dense(num_classes, activation='softmax'))

  model.summary()

  model.compile(loss=tensorflow.keras.losses.categorical_crossentropy,
                optimizer='adam',
                metrics=['accuracy'])

  model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            validation_data=(x_test, y_test))
  score = model.evaluate(x_test, y_test, verbose=0)
  print('Test loss:', score[0])
  print('Test accuracy:', score[1])
  
  return model

# %%
pawn_model = train_model(pawn_x_train, pawn_x_test, pawn_y_train, pawn_y_test)
rook_model = train_model(rook_x_train, rook_x_test, rook_y_train, rook_y_test)
knight_model = train_model(knight_x_train, knight_x_test, knight_y_train, knight_y_test)
bishop_model = train_model(bishop_x_train, bishop_x_test, bishop_y_train, bishop_y_test)
queen_model = train_model(queen_x_train, queen_x_test, queen_y_train, queen_y_test)
king_model = train_model(king_x_train, king_x_test, king_y_train, king_y_test)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 581016 samples, validate on 193673 samples
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 581016/581016 [==============================] - 50s 86us/sample - loss: 1.4261 - acc: 0.5256 - val_loss: 1.1863 - val_acc: 0.5872
# Epoch 2/15
# 581016/581016 [==============================] - 45s 78us/sample - loss: 1.1167 - acc: 0.6089 - val_loss: 1.1169 - val_acc: 0.6076
# Epoch 3/15
# 581016/581016 [==============================] - 47s 80us/sample - loss: 1.0552 - acc: 0.6268 - val_loss: 1.0732 - val_acc: 0.6219
# Epoch 4/15
# 581016/581016 [==============================] - 47s 81us/sample - loss: 1.0200 - acc: 0.6384 - val_loss: 1.0704 - val_acc: 0.6233
# Epoch 5/15
# 581016/581016 [==============================] - 47s 81us/sample - loss: 0.9943 - acc: 0.6472 - val_loss: 1.0528 - val_acc: 0.6270
# Epoch 6/15
# 581016/581016 [==============================] - 49s 85us/sample - loss: 0.9750 - acc: 0.6538 - val_loss: 1.0398 - val_acc: 0.6336
# Epoch 7/15
# 581016/581016 [==============================] - 47s 81us/sample - loss: 0.9594 - acc: 0.6587 - val_loss: 1.0398 - val_acc: 0.6312
# Epoch 8/15
# 581016/581016 [==============================] - 46s 80us/sample - loss: 0.9461 - acc: 0.6636 - val_loss: 1.0376 - val_acc: 0.6329
# Epoch 9/15
# 581016/581016 [==============================] - 44s 76us/sample - loss: 0.9347 - acc: 0.6681 - val_loss: 1.0438 - val_acc: 0.6330
# Epoch 10/15
# 581016/581016 [==============================] - 44s 76us/sample - loss: 0.9243 - acc: 0.6710 - val_loss: 1.0395 - val_acc: 0.6339
# Epoch 11/15
# 581016/581016 [==============================] - 44s 76us/sample - loss: 0.9160 - acc: 0.6740 - val_loss: 1.0492 - val_acc: 0.6337
# Epoch 12/15
# 581016/581016 [==============================] - 44s 75us/sample - loss: 0.9086 - acc: 0.6771 - val_loss: 1.0425 - val_acc: 0.6362
# Epoch 13/15
# 581016/581016 [==============================] - 44s 76us/sample - loss: 0.9016 - acc: 0.6791 - val_loss: 1.0498 - val_acc: 0.6348
# Epoch 14/15
# 581016/581016 [==============================] - 44s 76us/sample - loss: 0.8959 - acc: 0.6808 - val_loss: 1.0444 - val_acc: 0.6353
# Epoch 15/15
# 581016/581016 [==============================] - 44s 77us/sample - loss: 0.8904 - acc: 0.6833 - val_loss: 1.0533 - val_acc: 0.6348
# Test loss: 1.053289296110034
# Test accuracy: 0.6347865
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 351105 samples, validate on 117036 samples
# Epoch 1/15
# 351105/351105 [==============================] - 29s 82us/sample - loss: 2.3633 - acc: 0.3305 - val_loss: 1.9994 - val_acc: 0.3954
# Epoch 2/15
# 351105/351105 [==============================] - 26s 74us/sample - loss: 1.8900 - acc: 0.4192 - val_loss: 1.8431 - val_acc: 0.4303
# Epoch 3/15
# 351105/351105 [==============================] - 26s 74us/sample - loss: 1.7553 - acc: 0.4504 - val_loss: 1.7841 - val_acc: 0.4455
# Epoch 4/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.6723 - acc: 0.4717 - val_loss: 1.7454 - val_acc: 0.4517
# Epoch 5/15
# 351105/351105 [==============================] - 26s 74us/sample - loss: 1.6165 - acc: 0.4865 - val_loss: 1.7303 - val_acc: 0.4567
# Epoch 6/15
# 351105/351105 [==============================] - 26s 74us/sample - loss: 1.5734 - acc: 0.4963 - val_loss: 1.7160 - val_acc: 0.4634
# Epoch 7/15
# 351105/351105 [==============================] - 27s 76us/sample - loss: 1.5397 - acc: 0.5059 - val_loss: 1.7194 - val_acc: 0.4612
# Epoch 8/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.5123 - acc: 0.5146 - val_loss: 1.7168 - val_acc: 0.4624
# Epoch 9/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.4884 - acc: 0.5210 - val_loss: 1.7168 - val_acc: 0.4632
# Epoch 10/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.4686 - acc: 0.5267 - val_loss: 1.7199 - val_acc: 0.4638
# Epoch 11/15
# 351105/351105 [==============================] - 27s 75us/sample - loss: 1.4512 - acc: 0.5313 - val_loss: 1.7237 - val_acc: 0.4647
# Epoch 12/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.4364 - acc: 0.5354 - val_loss: 1.7392 - val_acc: 0.4591
# Epoch 13/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.4226 - acc: 0.5391 - val_loss: 1.7333 - val_acc: 0.4641
# Epoch 14/15
# 351105/351105 [==============================] - 27s 76us/sample - loss: 1.4106 - acc: 0.5429 - val_loss: 1.7404 - val_acc: 0.4623
# Epoch 15/15
# 351105/351105 [==============================] - 26s 75us/sample - loss: 1.3993 - acc: 0.5459 - val_loss: 1.7488 - val_acc: 0.4611
# Test loss: 1.7487769600771323
# Test accuracy: 0.46107182
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 378464 samples, validate on 126155 samples
# Epoch 1/15
# 378464/378464 [==============================] - 32s 83us/sample - loss: 1.3709 - acc: 0.5620 - val_loss: 1.0668 - val_acc: 0.6306
# Epoch 2/15
# 378464/378464 [==============================] - 28s 75us/sample - loss: 1.0039 - acc: 0.6459 - val_loss: 0.9750 - val_acc: 0.6557
# Epoch 3/15
# 378464/378464 [==============================] - 28s 75us/sample - loss: 0.9230 - acc: 0.6695 - val_loss: 0.9454 - val_acc: 0.6608
# Epoch 4/15
# 378464/378464 [==============================] - 28s 75us/sample - loss: 0.8748 - acc: 0.6837 - val_loss: 0.9265 - val_acc: 0.6693
# Epoch 5/15
# 378464/378464 [==============================] - 28s 74us/sample - loss: 0.8408 - acc: 0.6959 - val_loss: 0.9136 - val_acc: 0.6736
# Epoch 6/15
# 378464/378464 [==============================] - 28s 74us/sample - loss: 0.8141 - acc: 0.7044 - val_loss: 0.9106 - val_acc: 0.6741
# Epoch 7/15
# 378464/378464 [==============================] - 28s 75us/sample - loss: 0.7912 - acc: 0.7123 - val_loss: 0.9188 - val_acc: 0.6703
# Epoch 8/15
# 378464/378464 [==============================] - 28s 74us/sample - loss: 0.7718 - acc: 0.7184 - val_loss: 0.9163 - val_acc: 0.6760
# Epoch 9/15
# 378464/378464 [==============================] - 28s 73us/sample - loss: 0.7547 - acc: 0.7242 - val_loss: 0.9341 - val_acc: 0.6698
# Epoch 10/15
# 378464/378464 [==============================] - 28s 75us/sample - loss: 0.7403 - acc: 0.7293 - val_loss: 0.9254 - val_acc: 0.6747
# Epoch 11/15
# 378464/378464 [==============================] - 28s 74us/sample - loss: 0.7269 - acc: 0.7346 - val_loss: 0.9341 - val_acc: 0.6751
# Epoch 12/15
# 378464/378464 [==============================] - 28s 73us/sample - loss: 0.7152 - acc: 0.7387 - val_loss: 0.9424 - val_acc: 0.6726
# Epoch 13/15
# 378464/378464 [==============================] - 28s 74us/sample - loss: 0.7040 - acc: 0.7428 - val_loss: 0.9569 - val_acc: 0.6723
# Epoch 14/15
# 378464/378464 [==============================] - 28s 74us/sample - loss: 0.6934 - acc: 0.7458 - val_loss: 0.9543 - val_acc: 0.6734
# Epoch 15/15
# 378464/378464 [==============================] - 28s 75us/sample - loss: 0.6847 - acc: 0.7490 - val_loss: 0.9591 - val_acc: 0.6728
# Test loss: 0.9591333079364532
# Test accuracy: 0.672839
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 349557 samples, validate on 116519 samples
# Epoch 1/15
# 349557/349557 [==============================] - 29s 82us/sample - loss: 1.8354 - acc: 0.4272 - val_loss: 1.4749 - val_acc: 0.4977
# Epoch 2/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 1.3714 - acc: 0.5268 - val_loss: 1.3302 - val_acc: 0.5369
# Epoch 3/15
# 349557/349557 [==============================] - 27s 76us/sample - loss: 1.2593 - acc: 0.5580 - val_loss: 1.2854 - val_acc: 0.5488
# Epoch 4/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 1.1941 - acc: 0.5770 - val_loss: 1.2436 - val_acc: 0.5628
# Epoch 5/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 1.1472 - acc: 0.5910 - val_loss: 1.2387 - val_acc: 0.5648
# Epoch 6/15
# 349557/349557 [==============================] - 26s 76us/sample - loss: 1.1107 - acc: 0.6033 - val_loss: 1.2305 - val_acc: 0.5683
# Epoch 7/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 1.0812 - acc: 0.6130 - val_loss: 1.2243 - val_acc: 0.5714
# Epoch 8/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 1.0565 - acc: 0.6213 - val_loss: 1.2240 - val_acc: 0.5729
# Epoch 9/15
# 349557/349557 [==============================] - 27s 76us/sample - loss: 1.0349 - acc: 0.6281 - val_loss: 1.2293 - val_acc: 0.5703
# Epoch 10/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 1.0167 - acc: 0.6344 - val_loss: 1.2368 - val_acc: 0.5733
# Epoch 11/15
# 349557/349557 [==============================] - 27s 76us/sample - loss: 1.0001 - acc: 0.6402 - val_loss: 1.2373 - val_acc: 0.5711
# Epoch 12/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 0.9851 - acc: 0.6450 - val_loss: 1.2460 - val_acc: 0.5720
# Epoch 13/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 0.9714 - acc: 0.6500 - val_loss: 1.2458 - val_acc: 0.5729
# Epoch 14/15
# 349557/349557 [==============================] - 26s 75us/sample - loss: 0.9581 - acc: 0.6541 - val_loss: 1.2531 - val_acc: 0.5720
# Epoch 15/15
# 349557/349557 [==============================] - 27s 76us/sample - loss: 0.9473 - acc: 0.6577 - val_loss: 1.2611 - val_acc: 0.5741
# Test loss: 1.261144894621514
# Test accuracy: 0.5741295
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 261776 samples, validate on 87259 samples
# Epoch 1/15
# 261776/261776 [==============================] - 22s 83us/sample - loss: 2.4376 - acc: 0.3045 - val_loss: 2.0229 - val_acc: 0.3758
# Epoch 2/15
# 261776/261776 [==============================] - 19s 74us/sample - loss: 1.8985 - acc: 0.4013 - val_loss: 1.8550 - val_acc: 0.4076
# Epoch 3/15
# 261776/261776 [==============================] - 20s 76us/sample - loss: 1.7508 - acc: 0.4349 - val_loss: 1.7758 - val_acc: 0.4286
# Epoch 4/15
# 261776/261776 [==============================] - 19s 73us/sample - loss: 1.6600 - acc: 0.4583 - val_loss: 1.7351 - val_acc: 0.4388
# Epoch 5/15
# 261776/261776 [==============================] - 20s 76us/sample - loss: 1.5936 - acc: 0.4765 - val_loss: 1.7072 - val_acc: 0.4449
# Epoch 6/15
# 261776/261776 [==============================] - 20s 75us/sample - loss: 1.5401 - acc: 0.4915 - val_loss: 1.7015 - val_acc: 0.4475
# Epoch 7/15
# 261776/261776 [==============================] - 20s 75us/sample - loss: 1.4973 - acc: 0.5044 - val_loss: 1.7006 - val_acc: 0.4535
# Epoch 8/15
# 261776/261776 [==============================] - 20s 75us/sample - loss: 1.4612 - acc: 0.5148 - val_loss: 1.6930 - val_acc: 0.4504
# Epoch 9/15
# 261776/261776 [==============================] - 19s 74us/sample - loss: 1.4300 - acc: 0.5248 - val_loss: 1.6912 - val_acc: 0.4546
# Epoch 10/15
# 261776/261776 [==============================] - 20s 75us/sample - loss: 1.4026 - acc: 0.5325 - val_loss: 1.7008 - val_acc: 0.4562
# Epoch 11/15
# 261776/261776 [==============================] - 19s 74us/sample - loss: 1.3798 - acc: 0.5399 - val_loss: 1.6916 - val_acc: 0.4548
# Epoch 12/15
# 261776/261776 [==============================] - 20s 75us/sample - loss: 1.3586 - acc: 0.5453 - val_loss: 1.7073 - val_acc: 0.4556
# Epoch 13/15
# 261776/261776 [==============================] - 19s 74us/sample - loss: 1.3389 - acc: 0.5522 - val_loss: 1.7053 - val_acc: 0.4566
# Epoch 14/15
# 261776/261776 [==============================] - 20s 76us/sample - loss: 1.3221 - acc: 0.5567 - val_loss: 1.7190 - val_acc: 0.4592
# Epoch 15/15
# 261776/261776 [==============================] - 19s 74us/sample - loss: 1.3069 - acc: 0.5618 - val_loss: 1.7211 - val_acc: 0.4584
# Test loss: 1.7210995356797432
# Test accuracy: 0.4583596
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 225804 samples, validate on 75268 samples
# Epoch 1/15
# 225804/225804 [==============================] - 20s 90us/sample - loss: 1.5796 - acc: 0.4382 - val_loss: 1.1625 - val_acc: 0.5448
# Epoch 2/15
# 225804/225804 [==============================] - 17s 74us/sample - loss: 1.0935 - acc: 0.5686 - val_loss: 1.0762 - val_acc: 0.5717
# Epoch 3/15
# 225804/225804 [==============================] - 17s 73us/sample - loss: 1.0037 - acc: 0.6023 - val_loss: 1.0144 - val_acc: 0.5951
# Epoch 4/15
# 225804/225804 [==============================] - 17s 76us/sample - loss: 0.9490 - acc: 0.6234 - val_loss: 0.9946 - val_acc: 0.6041
# Epoch 5/15
# 225804/225804 [==============================] - 17s 75us/sample - loss: 0.9090 - acc: 0.6396 - val_loss: 0.9841 - val_acc: 0.6104
# Epoch 6/15
# 225804/225804 [==============================] - 17s 74us/sample - loss: 0.8760 - acc: 0.6540 - val_loss: 0.9744 - val_acc: 0.6150
# Epoch 7/15
# 225804/225804 [==============================] - 17s 74us/sample - loss: 0.8479 - acc: 0.6640 - val_loss: 0.9699 - val_acc: 0.6185
# Epoch 8/15
# 225804/225804 [==============================] - 17s 76us/sample - loss: 0.8221 - acc: 0.6761 - val_loss: 0.9838 - val_acc: 0.6138
# Epoch 9/15
# 225804/225804 [==============================] - 17s 74us/sample - loss: 0.7992 - acc: 0.6859 - val_loss: 0.9760 - val_acc: 0.6183
# Epoch 10/15
# 225804/225804 [==============================] - 17s 75us/sample - loss: 0.7798 - acc: 0.6953 - val_loss: 0.9838 - val_acc: 0.6181
# Epoch 11/15
# 225804/225804 [==============================] - 17s 74us/sample - loss: 0.7595 - acc: 0.7031 - val_loss: 0.9881 - val_acc: 0.6186
# Epoch 12/15
# 225804/225804 [==============================] - 17s 76us/sample - loss: 0.7418 - acc: 0.7098 - val_loss: 1.0022 - val_acc: 0.6147
# Epoch 13/15
# 225804/225804 [==============================] - 17s 74us/sample - loss: 0.7263 - acc: 0.7166 - val_loss: 1.0138 - val_acc: 0.6145
# Epoch 14/15
# 225804/225804 [==============================] - 17s 76us/sample - loss: 0.7118 - acc: 0.7233 - val_loss: 1.0165 - val_acc: 0.6141
# Epoch 15/15
# 225804/225804 [==============================] - 17s 73us/sample - loss: 0.6974 - acc: 0.7293 - val_loss: 1.0318 - val_acc: 0.6133
# Test loss: 1.0317502720022629
# Test accuracy: 0.6132885

# %%
bad = []
for i in range(len(pawn_x_test)):
  a = np.array([pawn_x_test[i]])
  b = pawn_model.predict(a)[0]
  
  index = np.argmax(b)
  rank = int(index / 8)
  file = index % 8
  
  square = pawn_x_test[i][rank][file]
  if 1 in square:
    bad.append(i)
    print(i, bad)

# %%
pawn_model.save('../models/20190213_pawn_convolution.h5')
rook_model.save('../models/20190213_rook_convolution.h5')
knight_model.save('../models/20190213_knight_convolution.h5')
bishop_model.save('../models/20190213_bishop_convolution.h5')
queen_model.save('../models/20190213_queen_convolution.h5')
king_model.save('../models/20190213_king_convolution.h5')

# %% [markdown]
# With these models trained from the extensive datasets, it will always select a valid move, and does well throughout the game, with the only exception being that the endgame sometimes gets repetitive.
#
# ![Example 1](Example6.PNG)
#
# Here is also an example of a midgame against the level 3 engine on chess.com
#
# ![Example 1](Example7.PNG)
#
# Using the model I have been able to defeat the level 3 engine, but did run into an issue where the moves would get kind of repetitive.
#
# ![Example 1](Example8.PNG)
#
# Overall though I would still consider this model a success even if some moves didn't work out correctly.
