# %% [markdown]
# ## Deep Learning Move Convolutional Engine
#
# By Evan Richardson

# %%
import tensorflow
print(tensorflow.__version__)

import numpy as np
import pandas as pd
# from google.colab import drive
from sklearn.model_selection import train_test_split
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Dense, Flatten
# Out:
# 1.13.0-rc1

# %%
# drive.mount('/content/gdrive')
df = pd.read_csv("../data/2018_games_dl_pred.csv")

# %%
df.head()
# Out:
#    Result  Move  Color  Piece  CurrentFile  CurrentRank  NewFile  NewRank  \
# 0       1     1      1      1            4            1        4        3
# 1       1     2      1      1            5            1        5        3
# 2       1     3      1      3            6            0        5        2
# 3       1     4      1      1            3            1        3        2
# 4       1     5      1      1            4            3        4        4
#
#     a1   b1 ...    g7   h7   a8   b8    c8    d8    e8    f8   g8   h8
# 0  2.0  3.0 ...   7.0  7.0  8.0  9.0  10.0  11.0  12.0  10.0  9.0  8.0
# 1  2.0  3.0 ...   7.0  7.0  8.0  9.0  10.0  11.0  12.0  10.0  9.0  8.0
# 2  2.0  3.0 ...   7.0  7.0  8.0  9.0  10.0  11.0  12.0  10.0  9.0  8.0
# 3  2.0  3.0 ...   7.0  7.0  8.0  NaN  10.0  11.0  12.0  10.0  9.0  8.0
# 4  2.0  3.0 ...   7.0  7.0  8.0  NaN  10.0  11.0  12.0  10.0  9.0  8.0
#
# [5 rows x 72 columns]

# %%
df.shape
# Out:
# (2863632, 72)

# %%
pawn_moves = df.loc[df['Piece'] == 1]
rook_moves = df.loc[df['Piece'] == 2]
knight_moves = df.loc[df['Piece'] == 3]
bishop_moves = df.loc[df['Piece'] == 4]
queen_moves = df.loc[df['Piece'] == 5]
king_moves = df.loc[df['Piece'] == 6]

print(pawn_moves.shape, rook_moves.shape, knight_moves.shape, bishop_moves.shape, queen_moves.shape, king_moves.shape)
# Out:
# (774689, 72) (468141, 72) (504619, 72) (466076, 72) (349035, 72) (301072, 72)

# %%
def translateGameStates(df):
  states = []

  for position in df.values:
    gameState = np.zeros((8, 8, 6))
    squares = position[-64:]

    for rank in range(8):
      for file in range(8):
        index = rank * 8 + file
        piece = squares[index]

        if piece > 6:
          gameState[rank][file][int(piece) - 7] = -1
        elif piece > 0:
          gameState[rank][file][int(piece) - 1] = 1

    states.append(gameState)

  return np.array(states)

# %%
def translateOutputSet(df, file_col, rank_col):
  states = []

  for position in df.values:
    state = np.zeros(64)

    file = position[file_col]
    rank = position[rank_col]

    state[int(rank) * 8 + int(file)] = 1
    states.append(state)

  return np.array(states)

# %%
def createTrainAndTestSets(df):
  train, test = train_test_split(df)
  print(df.shape, train.shape, test.shape)
  
  x_train = translateGameStates(train)
  x_test = translateGameStates(test)

  y_train = translateOutputSet(train, 6, 7)
  y_test = translateOutputSet(test, 6, 7)
  
  return (x_train, x_test, y_train, y_test)

# %%
pawn_x_train, pawn_x_test, pawn_y_train, pawn_y_test = createTrainAndTestSets(pawn_moves)
rook_x_train, rook_x_test, rook_y_train, rook_y_test = createTrainAndTestSets(rook_moves)
knight_x_train, knight_x_test, knight_y_train, knight_y_test = createTrainAndTestSets(knight_moves)
bishop_x_train, bishop_x_test, bishop_y_train, bishop_y_test = createTrainAndTestSets(bishop_moves)
queen_x_train, queen_x_test, queen_y_train, queen_y_test = createTrainAndTestSets(queen_moves)
king_x_train, king_x_test, king_y_train, king_y_test = createTrainAndTestSets(king_moves)
# Out:
# (774689, 72) (581016, 72) (193673, 72)
# (468141, 72) (351105, 72) (117036, 72)
# (504619, 72) (378464, 72) (126155, 72)
# (466076, 72) (349557, 72) (116519, 72)

# %%
input_shape = (8, 8, 6)
print(input_shape)
# Out:
# (8, 8, 6)

# %%
def train_model(x_train, x_test, y_train, y_test):
  batch_size = 250
  num_classes = 64
  epochs = 15

  model = Sequential()
  model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
  model.add(Conv2D(128, (3, 3), activation='relu'))
  model.add(Flatten())
  model.add(Dense(num_classes, activation='softmax'))

  model.summary()

  model.compile(loss=tensorflow.keras.losses.categorical_crossentropy,
                optimizer='adam',
                metrics=['accuracy'])

  model.fit(x_train, y_train,
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            validation_data=(x_test, y_test))
  score = model.evaluate(x_test, y_test, verbose=0)
  print('Test loss:', score[0])
  print('Test accuracy:', score[1])
  
  return model

# %%
pawn_model = train_model(pawn_x_train, pawn_x_test, pawn_y_train, pawn_y_test)
rook_model = train_model(rook_x_train, rook_x_test, rook_y_train, rook_y_test)
knight_model = train_model(knight_x_train, knight_x_test, knight_y_train, knight_y_test)
bishop_model = train_model(bishop_x_train, bishop_x_test, bishop_y_train, bishop_y_test)
queen_model = train_model(queen_x_train, queen_x_test, queen_y_train, queen_y_test)
king_model = train_model(king_x_train, king_x_test, king_y_train, king_y_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_16 (Conv2D)           (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 49771 samples, validate on 16591 samples
# Epoch 1/15
# 49771/49771 [==============================] - 2s 49us/sample - loss: 2.4559 - acc: 0.2964 - val_loss: 1.9282 - val_acc: 0.3991
# Epoch 2/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.7129 - acc: 0.4520 - val_loss: 1.5985 - val_acc: 0.4756
# Epoch 3/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.4697 - acc: 0.5170 - val_loss: 1.4623 - val_acc: 0.5146
# Epoch 4/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.3445 - acc: 0.5529 - val_loss: 1.3980 - val_acc: 0.5261
# Epoch 5/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.2631 - acc: 0.5747 - val_loss: 1.3298 - val_acc: 0.5509
# Epoch 6/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.2012 - acc: 0.5935 - val_loss: 1.2966 - val_acc: 0.5593
# Epoch 7/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.1465 - acc: 0.6110 - val_loss: 1.2918 - val_acc: 0.5627
# Epoch 8/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.1048 - acc: 0.6259 - val_loss: 1.2772 - val_acc: 0.5690
# Epoch 9/15
# 49771/49771 [==============================] - 2s 42us/sample - loss: 1.0616 - acc: 0.6375 - val_loss: 1.2697 - val_acc: 0.5715
# Epoch 10/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 1.0268 - acc: 0.6488 - val_loss: 1.2615 - val_acc: 0.5794
# Epoch 11/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 0.9958 - acc: 0.6595 - val_loss: 1.2756 - val_acc: 0.5754
# Epoch 12/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 0.9623 - acc: 0.6710 - val_loss: 1.2482 - val_acc: 0.5824
# Epoch 13/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 0.9314 - acc: 0.6803 - val_loss: 1.2608 - val_acc: 0.5584
# Epoch 14/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 0.9083 - acc: 0.6881 - val_loss: 1.2544 - val_acc: 0.5868
# Epoch 15/15
# 49771/49771 [==============================] - 2s 41us/sample - loss: 0.8810 - acc: 0.6989 - val_loss: 1.2641 - val_acc: 0.5850
# Test loss: 1.2641456897130432
# Test accuracy: 0.58501595
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_18 (Conv2D)           (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 29860 samples, validate on 9954 samples
# Epoch 1/15
# 29860/29860 [==============================] - 2s 56us/sample - loss: 3.6193 - acc: 0.1281 - val_loss: 3.2381 - val_acc: 0.1968
# Epoch 2/15
# 29860/29860 [==============================] - 1s 41us/sample - loss: 2.8438 - acc: 0.2539 - val_loss: 2.6534 - val_acc: 0.2774
# Epoch 3/15
# 29860/29860 [==============================] - 1s 42us/sample - loss: 2.4126 - acc: 0.3268 - val_loss: 2.4258 - val_acc: 0.3204
# Epoch 4/15
# 29860/29860 [==============================] - 1s 40us/sample - loss: 2.2032 - acc: 0.3676 - val_loss: 2.3195 - val_acc: 0.3310
# Epoch 5/15
# 29860/29860 [==============================] - 1s 41us/sample - loss:
15
# 22426/22426 [==============================] - 1s 42us/sample - loss: 1.4094 - acc: 0.5623 - val_loss: 2.1993 - val_acc: 0.3633
# Epoch 14/15
# 22426/22426 [==============================] - 1s 41us/sample - loss: 1.3256 - acc: 0.5879 - val_loss: 2.1962 - val_acc: 0.3749
# Epoch 15/15
# 22426/22426 [==============================] - 1s 42us/sample - loss: 1.2593 - acc: 0.6056 - val_loss: 2.2299 - val_acc: 0.3733
# Test loss: 2.2298979606138567
# Test accuracy: 0.37332797
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_26 (Conv2D)           (None, 6, 6, 32)          1760
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 4, 4, 128)         36992
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                131136
# =================================================================
# Total params: 169,888
# Trainable params: 169,888
# Non-trainable params: 0
# _________________________________________________________________
# Train on 19325 samples, validate on 6442 samples
# Epoch 1/15
# 19325/19325 [==============================] - 1s 70us/sample - loss: 3.4169 - acc: 0.1117 - val_loss: 2.7898 - val_acc: 0.2144
# Epoch 2/15
# 19325/19325 [==============================] - 1s 44us/sample - loss: 2.0839 - acc: 0.3152 - val_loss: 1.7402 - val_acc: 0.3662
# Epoch 3/15
# 19325/19325 [==============================] - 1s 41us/sample - loss: 1.5845 - acc: 0.4130 - val_loss: 1.5544 - val_acc: 0.4191
# Epoch 4/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 1.4150 - acc: 0.4624 - val_loss: 1.4743 - val_acc: 0.4364
# Epoch 5/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 1.3171 - acc: 0.4935 - val_loss: 1.3997 - val_acc: 0.4758
# Epoch 6/15
# 19325/19325 [==============================] - 1s 43us/sample - loss: 1.2236 - acc: 0.5324 - val_loss: 1.3465 - val_acc: 0.4790
# Epoch 7/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 1.1418 - acc: 0.5610 - val_loss: 1.3161 - val_acc: 0.4995
# Epoch 8/15
# 19325/19325 [==============================] - 1s 41us/sample - loss: 1.0799 - acc: 0.5877 - val_loss: 1.3037 - val_acc: 0.5020
# Epoch 9/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 1.0251 - acc: 0.6109 - val_loss: 1.2592 - val_acc: 0.5217
# Epoch 10/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 0.9769 - acc: 0.6306 - val_loss: 1.2672 - val_acc: 0.5144
# Epoch 11/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 0.9242 - acc: 0.6488 - val_loss: 1.2297 - val_acc: 0.5267
# Epoch 12/15
# 19325/19325 [==============================] - 1s 43us/sample - loss: 0.8752 - acc: 0.6707 - val_loss: 1.2579 - val_acc: 0.5251
# Epoch 13/15
# 19325/19325 [==============================] - 1s 41us/sample - loss: 0.8348 - acc: 0.6871 - val_loss: 1.2547 - val_acc: 0.5306
# Epoch 14/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 0.7994 - acc: 0.7058 - val_loss: 1.2641 - val_acc: 0.5298
# Epoch 15/15
# 19325/19325 [==============================] - 1s 42us/sample - loss: 0.7604 - acc: 0.7219 - val_loss: 1.2659 - val_acc: 0.5338
# Test loss: 1.2658953237000625
# Test accuracy: 0.5338404

# %%
bad = []
for i in range(len(pawn_x_test)):
  a = np.array([pawn_x_test[i]])
  b = pawn_model.predict(a)[0]
  
  index = np.argmax(b)
  rank = int(index / 8)
  file = index % 8
  
  square = pawn_x_test[i][rank][file]
  if 1 in square:
    bad.append(i)
    print(i, bad)

# %%
pawn_model.save('/content/gdrive/My Drive/Colab Notebooks/chess/20190213_pawn_convolution.h5')
rook_model.save('/content/gdrive/My Drive/Colab Notebooks/chess/20190213_rook_convolution.h5')
knight_model.save('/content/gdrive/My Drive/Colab Notebooks/chess/20190213_knight_convolution.h5')
bishop_model.save('/content/gdrive/My Drive/Colab Notebooks/chess/20190213_bishop_convolution.h5')
queen_model.save('/content/gdrive/My Drive/Colab Notebooks/chess/20190213_queen_convolution.h5')
king_model.save('/content/gdrive/My Drive/Colab Notebooks/chess/20190213_king_convolution.h5')
